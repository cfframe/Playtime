# %% [markdown]
# Using as sandbox, doesn't matter if don't save

# %% [markdown]
# TestNow bug, not sent yet: Lists snippet produces incorrect output
#
# Text for step 10 says ...
# ```
# For example, the following snippet prints ['b', 'd'] to the screen:
# print((1,2,3)[4:5])
# ```
# ...but it produces an empty tuple `()`.
# One way to fix is to change the code to:
# ```
# the_list = ['a', 'b', 'c', 'd', 'e', 'f']
# print(the_list[1:4:2])
# ```

# %%
print((1,2,3)[4:5])
# Out:
# ()

# %%
the_list = ['a', 'b', 'c', 'd', 'e', 'f']
print(the_list[1:4:2])
# Out:
# ['b', 'd']

# %%
# invalid syntax
the_list[]
# Out:
#   Cell In[3], line 2
#     the_list[]
#              ^
# SyntaxError: invalid syntax

# %%
the_list * 2
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f', 'a', 'b', 'c', 'd', 'e', 'f']

# %%
# A 
def sample (value) :
    return total + value

total = 0
# new_total = sample()
new_total = sample(total)
print (total)
# Out:
# 0

# %% [markdown]
# PCEP checks

# %%
# tuple list slicing index
list_1 = []
list_1.append(1)
list_1.insert(0, 2)
dupes = list_1
dupes.append(3)
print(len(list_1), len(dupes))
# Out:
# 3 3

# %%
increment = 1

while increment < 10:
    increment += 1
    if increment == 7:
        break
    print('*', end='')
else:    
    print('*', end='')
# Out:
# *****

# %%
def my_function(parameter):
    parameter[0] = 1
    return parameter[0]

my_list = [0]

my_function(my_list)
print(my_list[0])
# Out:
# 1
